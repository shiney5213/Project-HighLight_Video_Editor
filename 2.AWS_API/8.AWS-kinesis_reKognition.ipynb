# %% [markdown]
# https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/rekognition.html#Rekognition.Client.detect_text

# %%
import time
import boto3
import urllib.request, json

# %%
AWS_ACCESS_KEY_ID = 'AKIAS3UCLIDDHDXHMWOZ'
AWS_SECRET_ACCESS_KEY = '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'
AWS_DEFAULT_REGION = 'ap-northeast-2'

# %%
session = boto3.Session(
                     aws_access_key_id = AWS_ACCESS_KEY_ID,
                    aws_secret_access_key = AWS_SECRET_ACCESS_KEY,
                    region_name = AWS_DEFAULT_REGION)
s3 = session.resource('s3')
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# eyshin
# hoseong
# iskang-gsc
# namho
# rekognition-video-console-demo-icn-multicampus-pl9kfnqvmco2pou
# serveruploadbucket

# %%
client=boto3.client('rekognition',
                      aws_access_key_id=AWS_ACCESS_KEY_ID,
                      aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
                      region_name=AWS_DEFAULT_REGION
                      )

# %% [markdown]
# ### detect_faces

# %%
def detect_faces(photo, bucket):

    response = client.detect_faces(
        Image={'S3Object':{'Bucket':bucket,'Name':photo}},
        Attributes=['ALL'])

    print('Detected faces for ' + photo)    
    for faceDetail in response['FaceDetails']:
        print('The detected face is between ' + str(faceDetail['AgeRange']['Low']) 
              + ' and ' + str(faceDetail['AgeRange']['High']) + ' years old')
        print('Here are the other attributes:')
        print(json.dumps(faceDetail, indent=4, sort_keys=True))
    return len(response['FaceDetails'])

# %%
photo='Daniel.jpg'
bucket='namho'
face_count=detect_faces(photo, bucket)
# print("Faces detected: " + str(face_count))
# Out:
# Detected faces for Daniel.jpg
# The detected face is between 42 and 60 years old
# Here are the other attributes:
# {
#     "AgeRange": {
#         "High": 60,
#         "Low": 42
#     },
#     "Beard": {
#         "Confidence": 96.43592071533203,
#         "Value": false
#     },
#     "BoundingBox": {
#         "Height": 0.5298784375190735,
#         "Left": 0.4559006989002228,
#         "Top": 0.11767934262752533,
#         "Width": 0.21163509786128998
#     },
#     "Confidence": 100.0,
#     "Emotions": [
#         {
#             "Confidence": 2.2601585388183594,
#             "Type": "FEAR"
#         },
#         {
#             "Confidence": 6.213204383850098,
#             "Type": "SURPRISED"
#         },
#         {
#             "Confidence": 25.460704803466797,
#             "Type": "CALM"
#         },
#         {
#             "Confidence": 4.405284881591797,
#             "Type": "DISGUSTED"
#         },
#         {
#             "Confidence": 1.3067888021469116,
#             "Type": "SAD"
#         },
#         {
#             "Confidence": 20.924238204956055,
#             "Type": "ANGRY"
#         },
#         {
#             "Confidence": 32.57036209106445,
#             "Type": "HAPPY"
#         },
#         {
#             "Confidence": 6.859258651733398,
#             "Type": "CONFUSED"
#         }
#     ],
#     "Eyeglasses": {
#         "Confidence": 99.80500793457031,
#         "Value": false
#     },
#     "EyesOpen": {
#         "Confidence": 99.98027038574219,
#         "Value": true
#     },
#     "Gender": {
#         "Confidence": 99.48265075683594,
#         "Value": "Male"
#     },
#     "Landmarks": [
#         {
#             "Type": "eyeLeft",
#             "X": 0.5025470852851868,
#             "Y": 0.34222954511642456
#         },
#         {
#             "Type": "eyeRight",
#             "X": 0.5921871066093445,
#             "Y": 0.35781049728393555
#         },
#         {
#             "Type": "mouthLeft",
#             "X": 0.503288984298706,
#             "Y": 0.5181875824928284
#         },
#         {
#             "Type": "mouthRight",
#             "X": 0.5771881341934204,
#             "Y": 0.5316905975341797
#         },
#         {
#             "Type": "nose",
#             "X": 0.5324811935424805,
#             "Y": 0.44776347279548645
#         },
#         {
#             "Type": "leftEyeBrowLeft",
#             "X": 0.4734024107456207,
#             "Y": 0.2935754060745239
#         },
#         {
#             "Type": "leftEyeBrowRight",
#             "X": 0.5188292264938354,
#             "Y": 0.29599010944366455
#         },
#         {
#             "Type": "leftEyeBrowUp",
#             "X": 0.4954538345336914,
#             "Y": 0.2810428738594055
#         },
#         {
#             "Type": "rightEyeBrowLeft",
#             "X": 0.571418285369873,
#             "Y": 0.3044876158237457
#         },
#         {
#             "Type": "rightEyeBrowRight",
#             "X": 0.6333876848220825,
#             "Y": 0.3216403126716614
#         },
#         {
#             "Type": "rightEyeBrowUp",
#             "X": 0.600863516330719,
#             "Y": 0.29903098940849304
#         },
#         {
#             "Type": "leftEyeLeft",
#             "X": 0.48913323879241943,
#             "Y": 0.33637097477912903
#         },
#         {
#             "Type": "leftEyeRight",
#             "X": 0.5206620693206787,
#             "Y": 0.3452271819114685
#         },
#         {
#             "Type": "leftEyeUp",
#             "X": 0.5027220249176025,
#             "Y": 0.3327445089817047
#         },
#         {
#             "Type": "leftEyeDown",
#             "X": 0.5030447840690613,
#             "Y": 0.34834200143814087
#         },
#         {
#             "Type": "rightEyeLeft",
#             "X": 0.5740576982498169,
#             "Y": 0.3541162312030792
#         },
#         {
#             "Type": "rightEyeRight",
#             "X": 0.6088950037956238,
#             "Y": 0.3565747141838074
#         },
#         {
#             "Type": "rightEyeUp",
#             "X": 0.5915088057518005,
#             "Y": 0.3476710021495819
#         },
#         {
#             "Type": "rightEyeDown",
#             "X": 0.5906141400337219,
#             "Y": 0.3631930947303772
#         },
#         {
#             "Type": "noseLeft",
#             "X": 0.5210508108139038,
#             "Y": 0.4625357687473297
#         },
#         {
#             "Type": "noseRight",
#             "X": 0.5552798509597778,
#             "Y": 0.46493908762931824
#         },
#         {
#             "Type": "mouthUp",
#             "X": 0.5353736877441406,
#             "Y": 0.5046350955963135
#         },
#         {
#             "Type": "mouthDown",
#             "X": 0.5349924564361572,
#             "Y": 0.5548727512359619
#         },
#         {
#             "Type": "leftPupil",
#             "X": 0.5025470852851868,
#             "Y": 0.34222954511642456
#         },
#         {
#             "Type": "rightPupil",
#             "X": 0.5921871066093445,
#             "Y": 0.35781049728393555
#         },
#         {
#             "Type": "upperJawlineLeft",
#             "X": 0.46755632758140564,
#             "Y": 0.32205936312675476
#         },
#         {
#             "Type": "midJawlineLeft",
#             "X": 0.4759562611579895,
#             "Y": 0.5145394206047058
#         },
#         {
#             "Type": "chinBottom",
#             "X": 0.5364987850189209,
#             "Y": 0.6414738297462463
#         },
#         {
#             "Type": "midJawlineRight",
#             "X": 0.6380583047866821,
#             "Y": 0.5418540835380554
#         },
#         {
#             "Type": "upperJawlineRight",
#             "X": 0.6693716049194336,
#             "Y": 0.3559305667877197
#         }
#     ],
#     "MouthOpen": {
#         "Confidence": 59.20233917236328,
#         "Value": true
#     },
#     "Mustache": {
#         "Confidence": 99.56754302978516,
#         "Value": false
#     },
#     "Pose": {
#         "Pitch": -0.971230149269104,
#         "Roll": 3.5931825637817383,
#         "Yaw": -7.669366836547852
#     },
#     "Quality": {
#         "Brightness": 49.13550567626953,
#         "Sharpness": 95.51618957519531
#     },
#     "Smile": {
#         "Confidence": 66.45034790039062,
#         "Value": false
#     },
#     "Sunglasses": {
#         "Confidence": 99.9402847290039,
#         "Value": false
#     }
# }

# %% [markdown]
# ## detect_text

# %%
def detect_text(photo, bucket):

    response=client.detect_text(
        Image={'S3Object':{'Bucket':bucket,'Name':photo}})
    textDetections=response['TextDetections']
    
#     print (textDetections)
    for text in textDetections:
            print ('Detected text:' + text['DetectedText'])
            print ('Confidence: ' + "{:.2f}".format(text['Confidence']) + "%")
            print ('Id: {}'.format(text['Id']))
            if 'ParentId' in text:
                print ('Parent Id: {}'.format(text['ParentId']))
            print ('Type:' + text['Type'])
            print()
    return len(textDetections)

# %%
photo = 'test.png'
bucket = 'eyshin'

detect_text(photo, bucket)
# Out:
# Detected text:OtLI HOI
# Confidence: 85.28%
# Id: 0
# Type:LINE
#
# Detected text:rlo
# Confidence: 96.41%
# Id: 1
# Type:LINE
#
# Detected text:O? 4.1
# Confidence: 70.00%
# Id: 2
# Type:LINE
#
# Detected text:L
# Confidence: 78.01%
# Id: 3
# Type:LINE
#
# Detected text:NIE. HI,
# Confidence: 77.89%
# Id: 4
# Type:LINE
#
# Detected text:uto!
# Confidence: 73.64%
# Id: 5
# Type:LINE
#
# Detected text:OtLI
# Confidence: 86.33%
# Id: 6
# Parent Id: 0
# Type:WORD
#
# Detected text:HOI
# Confidence: 84.23%
# Id: 7
# Parent Id: 0
# Type:WORD
#
# Detected text:rlo
# Confidence: 96.41%
# Id: 8
# Parent Id: 1
# Type:WORD
#
# Detected text:O?
# Confidence: 78.09%
# Id: 9
# Parent Id: 2
# Type:WORD
#
# Detected text:4.1
# Confidence: 61.91%
# Id: 10
# Parent Id: 2
# Type:WORD
#
# Detected text:L
# Confidence: 78.01%
# Id: 11
# Parent Id: 3
# Type:WORD
#
# Detected text:HI,
# Confidence: 79.67%
# Id: 13
# Parent Id: 4
# Type:WORD
#
# Detected text:NIE.
# Confidence: 76.11%
# Id: 12
# Parent Id: 4
# Type:WORD
#
# Detected text:uto!
# Confidence: 73.64%
# Id: 14
# Parent Id: 5
# Type:WORD
# 15

# %%
photo = 'test-en.jpg'
bucket = 'eyshin'

detect_text(photo, bucket)
# Out:
# Detected text:COMING ASHORE SOON.
# Confidence: 99.93%
# Id: 0
# Type:LINE
#
# Detected text:Og CARBS I Og
# Confidence: 92.59%
# Id: 1
# Type:LINE
#
# Detected text:SUGARS I 90 CALS
# Confidence: 94.59%
# Id: 2
# Type:LINE
#
# Detected text:E
# Confidence: 53.78%
# Id: 3
# Type:LINE
#
# Detected text:ARR
# Confidence: 53.25%
# Id: 4
# Type:LINE
#
# Detected text:8AE
# Confidence: 59.61%
# Id: 5
# Type:LINE
#
# Detected text:SELTZER
# Confidence: 99.89%
# Id: 6
# Type:LINE
#
# Detected text:SELTZER
# Confidence: 99.04%
# Id: 7
# Type:LINE
#
# Detected text:SELTZER
# Confidence: 99.55%
# Id: 8
# Type:LINE
#
# Detected text:orona
# Confidence: 99.78%
# Id: 9
# Type:LINE
#
# Detected text:Qorona
# Confidence: 95.17%
# Id: 10
# Type:LINE
#
# Detected text:Corona
# Confidence: 93.64%
# Id: 11
# Type:LINE
#
# Detected text:RLITRERY Corona AB SELTZER
# Confidence: 84.04%
# Id: 12
# Type:LINE
#
# Detected text:CREET
# Confidence: 73.07%
# Id: 13
# Type:LINE
#
# Detected text:TEIAL
# Confidence: 85.89%
# Id: 14
# Type:LINE
#
# Detected text:COMING
# Confidence: 99.99%
# Id: 15
# Parent Id: 0
# Type:WORD
#
# Detected text:ASHORE
# Confidence: 99.99%
# Id: 16
# Parent Id: 0
# Type:WORD
#
# Detected text:SOON.
# Confidence: 99.83%
# Id: 17
# Parent Id: 0
# Type:WORD
#
# Detected text:Og
# Confidence: 90.98%
# Id: 18
# Parent Id: 1
# Type:WORD
#
# Detected text:CARBS
# Confidence: 99.98%
# Id: 19
# Parent Id: 1
# Type:WORD
#
# Detected text:I
# Confidence: 81.44%
# Id: 20
# Parent Id: 1
# Type:WORD
#
# Detected text:Og
# Confidence: 97.96%
# Id: 21
# Parent Id: 1
# Type:WORD
#
# Detected text:SUGARS
# Confidence: 99.95%
# Id: 22
# Parent Id: 2
# Type:WORD
#
# Detected text:I
# Confidence: 78.64%
# Id: 23
# Parent Id: 2
# Type:WORD
#
# Detected text:90
# Confidence: 99.82%
# Id: 24
# Parent Id: 2
# Type:WORD
#
# Detected text:CALS
# Confidence: 99.97%
# Id: 25
# Parent Id: 2
# Type:WORD
#
# Detected text:E
# Confidence: 53.78%
# Id: 26
# Parent Id: 3
# Type:WORD
#
# Detected text:ARR
# Confidence: 53.25%
# Id: 27
# Parent Id: 4
# Type:WORD
#
# Detected text:AB
# Confidence: 68.80%
# Id: 37
# Parent Id: 12
# Type:WORD
#
# Detected text:8AE
# Confidence: 59.61%
# Id: 28
# Parent Id: 5
# Type:WORD
#
# Detected text:SELTZER
# Confidence: 99.55%
# Id: 31
# Parent Id: 8
# Type:WORD
#
# Detected text:SELTZER
# Confidence: 99.89%
# Id: 38
# Parent Id: 12
# Type:WORD
#
# Detected text:SELTZER
# Confidence: 99.89%
# Id: 29
# Parent Id: 6
# Type:WORD
#
# Detected text:SELTZER
# Confidence: 99.04%
# Id: 30
# Parent Id: 7
# Type:WORD
#
# Detected text:Corona
# Confidence: 93.64%
# Id: 34
# Parent Id: 11
# Type:WORD
#
# Detected text:Corona
# Confidence: 96.88%
# Id: 36
# Parent Id: 12
# Type:WORD
#
# Detected text:Qorona
# Confidence: 95.17%
# Id: 33
# Parent Id: 10
# Type:WORD
#
# Detected text:orona
# Confidence: 99.78%
# Id: 32
# Parent Id: 9
# Type:WORD
#
# Detected text:CREET
# Confidence: 73.07%
# Id: 39
# Parent Id: 13
# Type:WORD
#
# Detected text:RLITRERY
# Confidence: 70.60%
# Id: 35
# Parent Id: 12
# Type:WORD
#
# Detected text:TEIAL
# Confidence: 85.89%
# Id: 40
# Parent Id: 14
# Type:WORD
# 41
